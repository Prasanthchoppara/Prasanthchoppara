# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasanthchoppara/Prasanthchoppara/blob/main/salary_data_slr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('Salary_Data_SLR.csv')

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# Independent (X)
X=data.iloc[:,0].values
X=X.reshape(-1,1)

# %%
#Dependent (Y)
Y=data.iloc[:,-1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
Y
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train
# Out:
# array([[ 4.1],
#        [ 7.9],
#        [ 3. ],
#        [ 8.7],
#        [ 3.2],
#        [ 4.5],
#        [ 2.9],
#        [10.5],
#        [ 2.2],
#        [ 2. ],
#        [ 9.6],
#        [ 3.2],
#        [ 1.1],
#        [ 9.5],
#        [ 4. ],
#        [ 1.3],
#        [ 3.7],
#        [ 5.1],
#        [ 7.1],
#        [ 1.5],
#        [ 4. ],
#        [ 3.9],
#        [ 8.2],
#        [ 6.8]])

# %%
Y_test
# Out:
#     YearsExperience    Salary
# 17              5.3   83088.0
# 25              9.0  105582.0
# 28             10.3  122391.0
# 19              6.0   93940.0
# 15              4.9   67938.0
# 18              5.9   81363.0

# %%
X_train
# Out:
# array([[ 4.1],
#        [ 7.9],
#        [ 3. ],
#        [ 8.7],
#        [ 3.2],
#        [ 4.5],
#        [ 2.9],
#        [10.5],
#        [ 2.2],
#        [ 2. ],
#        [ 9.6],
#        [ 3.2],
#        [ 1.1],
#        [ 9.5],
#        [ 4. ],
#        [ 1.3],
#        [ 3.7],
#        [ 5.1],
#        [ 7.1],
#        [ 1.5],
#        [ 4. ],
#        [ 3.9],
#        [ 8.2],
#        [ 6.8]])

# %%
Y_train
# Out:
#     YearsExperience    Salary
# 13              4.1   57081.0
# 22              7.9  101302.0
# 6               3.0   60150.0
# 24              8.7  109431.0
# 7               3.2   54445.0
# 14              4.5   61111.0
# 5               2.9   56642.0
# 29             10.5  121872.0
# 4               2.2   39891.0
# 3               2.0   43525.0
# 27              9.6  112635.0
# 8               3.2   64445.0
# 0               1.1   39343.0
# 26              9.5  116969.0
# 11              4.0   55794.0
# 1               1.3   46205.0
# 9               3.7   57189.0
# 16              5.1   66029.0
# 21              7.1   98273.0
# 2               1.5   37731.0
# 12              4.0   56957.0
# 10              3.9   63218.0
# 23              8.2  113812.0
# 20              6.8   91738.0

# %%
#Y=f(X)=aX+b
from sklearn.linear_model import LinearRegression
regressor=LinearRegression().fit(X_train,Y_train)
print(regressor.intercept_,
regressor.coef_)
# Out:
# [8.88178420e-16 2.51772743e+04] [[1.00000000e+00]
#  [9.50452049e+03]]

# %%
regressor.predict(X_test)
# Out:
# array([[5.30000000e+00, 7.55512329e+04],
#        [9.00000000e+00, 1.10717959e+05],
#        [1.03000000e+01, 1.23073835e+05],
#        [6.00000000e+00, 8.22043972e+04],
#        [4.90000000e+00, 7.17494247e+04],
#        [5.90000000e+00, 8.12539451e+04]])

# %%
Y_test
# Out:
#     YearsExperience    Salary
# 17              5.3   83088.0
# 25              9.0  105582.0
# 28             10.3  122391.0
# 19              6.0   93940.0
# 15              4.9   67938.0
# 18              5.9   81363.0

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('salary v/s experience')
plt.xlabel('years of experience')
plt.ylabel('salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-9777cc39547a> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(X_train,Y_train,color='red')
#       3 plt.plot(X_train,regressor.predict(X_train),color='blue')
#       4 plt.title('salary v/s experience')
#       5 plt.xlabel('years of experience')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...
